# %%
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme

set_nb_theme('chesterish')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #cdd2e9;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #a2b0c7;
#  background-color: #1a2028;
#  background: #1a2028;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1a2028;
#  background: #1a2028;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #a2b0c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #dbe1ea;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('Google.csv')
dataset
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df = dataset.copy()
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include='O')
# Out:
#            App Category Reviews                Size    Installs   Type  Price  \
# count    10841    10841   10841               10841       10841  10840  10841
# unique    9660       34    6002                 462          22      3     93
# top     ROBLOX   FAMILY       0  Varies with device  1,000,000+   Free      0
# freq         9     1972     596                1695        1579  10039  10040
#
#        Content Rating Genres    Last Updated         Current Ver Android Ver
# count           10840  10841           10841               10833       10838
# unique              6    120            1378                2832          33
# top          Everyone  Tools  August 3, 2018  Varies with device  4.1 and up
# freq             8714    842             326                1459        2451

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df['Rating'].sort_values(ascending=False)
# Out:
# 10472    19.0
# 9511      5.0
# 10166     5.0
# 7895      5.0
# 5118      5.0
#          ...
# 10824     NaN
# 10825     NaN
# 10831     NaN
# 10835     NaN
# 10838     NaN
# Name: Rating, Length: 10841, dtype: float64

# %%
df['Rating'].describe()
# Out:
# count    9367.000000
# mean        4.193338
# std         0.537431
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64

# %%
df['Rating'].mode()
# Out:
# 0    4.4
# Name: Rating, dtype: float64

# %%
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
df['Rating'].max()
# Out:
# 19.0

# %%
sns.boxplot(df['Rating'])
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# One outlier is found
df[df['Rating'] == 19]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df['Rating'].value_counts()
# Out:
# 4.4     1109
# 4.3     1076
# 4.5     1038
# 4.2      952
# 4.6      823
# 4.1      708
# 4.0      568
# 4.7      499
# 3.9      386
# 3.8      303
# 5.0      274
# 3.7      239
# 4.8      234
# 3.6      174
# 3.5      163
# 3.4      128
# 3.3      102
# 4.9       87
# 3.0       83
# 3.1       69
# 3.2       64
# 2.9       45
# 2.8       42
# 2.7       25
# 2.6       25
# 2.5       21
# 2.3       20
# 2.4       19
# 1.0       16
# 2.2       14
# 1.9       13
# 2.0       12
# 1.7        8
# 1.8        8
# 2.1        8
# 1.6        4
# 1.4        3
# 1.5        3
# 1.2        1
# 19.0       1
# Name: Rating, dtype: int64

# %%
# Removing outlier from the column
df1 = df[df.index!=10472]

# %%
df1.shape
# Out:
# (10840, 13)

# %%
print(df1.Rating.mean())
print(df1.Rating.median())
print(df1.Rating.mode())
# Out:
# 4.192878228782186
# 4.2
# 0    4.2
# Name: Rating, dtype: float64

# %%
df1.Rating.fillna(4.2,inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12820\1975522118.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.Rating.fillna(4.2,inplace=True)

# %%
df1.Rating.isnull().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
df['Current Ver']
# Out:
# 0                     1.0.0
# 1                     2.0.0
# 2                     1.2.4
# 3        Varies with device
# 4                       1.1
#                 ...
# 10836                  1.48
# 10837                   1.0
# 10838                   1.0
# 10839    Varies with device
# 10840    Varies with device
# Name: Current Ver, Length: 10841, dtype: object

# %%
df['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       dtype=object)

# %%
df['Current Ver'].value_counts()
# Out:
# Varies with device    1459
# 1.0                    809
# 1.1                    264
# 1.2                    178
# 2.0                    151
#                       ...
# 1.0.17.3905              1
# 15.1.2                   1
# 4.94.19                  1
# 1.1.11.11                1
# 2.0.148.0                1
# Name: Current Ver, Length: 2832, dtype: int64

# %%
df1['Current Ver'].fillna('Varies with device',inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5472\4234683671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Current Ver'].fillna('Varies with device',inplace=True)

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       2
# dtype: int64

# %%
df1['Type'].unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
df1['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# Name: Type, dtype: int64

# %%
sns.countplot(df1['Type'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
10039+800
# Out:
# 10839

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#                             App         Category  Rating Reviews  \
# 4453     [substratum] Vacuum: P  PERSONALIZATION     4.4     230
# 4490       Pi Dark [substratum]  PERSONALIZATION     4.5     189
# 9148  Command & Conquer: Rivals           FAMILY     4.3       0
#
#                     Size Installs  Type  Price Content Rating  \
# 4453                 11M   1,000+  Paid  $1.49       Everyone
# 4490                2.1M  10,000+  Free      0       Everyone
# 9148  Varies with device        0   NaN      0   Everyone 10+
#
#                Genres    Last Updated         Current Ver         Android Ver
# 4453  Personalization   July 20, 2018                 4.4                 NaN
# 4490  Personalization  March 27, 2018                 1.1                 NaN
# 9148         Strategy   June 28, 2018  Varies with device  Varies with device

# %%
df1['Type'].fillna('Free',inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5472\2071554488.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Type'].fillna('Free',inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  object
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10840 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.4+ MB

# %%
df1['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df1['Android Ver'].value_counts()
# Out:
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#                          App         Category  Rating Reviews  Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230   11M   1,000+
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189  2.1M  10,000+
#
#       Type  Price Content Rating           Genres    Last Updated Current Ver  \
# 4453  Paid  $1.49       Everyone  Personalization   July 20, 2018         4.4
# 4490  Free      0       Everyone  Personalization  March 27, 2018         1.1
#
#      Android Ver
# 4453         NaN
# 4490         NaN

# %%
df1['Android Ver'].describe()
# Out:
# count          10838
# unique            33
# top       4.1 and up
# freq            2451
# Name: Android Ver, dtype: object

# %%
df1['Android Ver'].fillna('4.1 and up',inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5472\3515004664.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Android Ver'].fillna('4.1 and up',inplace=True)

# %%
df1[df1.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df1['Android Ver'].describe()
# Out:
# count          10840
# unique            33
# top       4.1 and up
# freq            2453
# Name: Android Ver, dtype: object

# %%
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# Avg Rating
df1['Rating'].mean()
# Out:
# 4.206476014760287

# %%
# Unique category
df1['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
# Number of unique category
df1['Category'].nunique()
# Out:
# 33

# %%
# 5 star rating
len(df1[df1['Rating'] == 5.0])
# Out:
# 274

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  object
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10840 non-null  object
#  12  Android Ver     10840 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.4+ MB

# %%
df1['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df1['Reviews'].nunique()
# Out:
# 6001

# %%
df1['Reviews'].value_counts()
# Out:
# 0         596
# 1         272
# 2         214
# 3         175
# 4         137
#          ...
# 4272        1
# 5517        1
# 4057        1
# 459797      1
# 398307      1
# Name: Reviews, Length: 6001, dtype: int64

# %%
# Converting possible categorical column into numerical

df1['Reviews'] = df1['Reviews'].astype('float')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5472\2945320784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Reviews'] = df1['Reviews'].astype('float')

# %%
df1['Reviews'].describe()
# Out:
# count    1.084000e+04
# mean     4.441529e+05
# std      2.927761e+06
# min      0.000000e+00
# 25%      3.800000e+01
# 50%      2.094000e+03
# 75%      5.477550e+04
# max      7.815831e+07
# Name: Reviews, dtype: float64

# %%
df1['Size']
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10840, dtype: object

# %%
df1['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
# M, K, Varies with device

# %%
# Removing M and K

def size_op(x):
    if 'M' in x:
        return float(x.replace('M',''))
    elif 'Varies with device' in x:
        return None
    elif 'k' in x:
        return (float(x.replace('k',''))/1000)

# %%
df1['Size'] = df1['Size'].apply(size_op)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5472\1375987645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Size'] = df1['Size'].apply(size_op)

# %%
df1['Size']
# Out:
# 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10836    53.0
# 10837     3.6
# 10838     9.5
# 10839     NaN
# 10840    19.0
# Name: Size, Length: 10840, dtype: float64

# %%
df1['Size'].describe()
# Out:
# count    9145.000000
# mean       21.516530
# std        22.588748
# min         0.008500
# 25%         4.900000
# 50%        13.000000
# 75%        30.000000
# max       100.000000
# Name: Size, dtype: float64

# %%
df1['Size'].isnull().sum()
# Out:
# 1695

# %%
df1['Size'].mode()
# Out:
# 0    11.0
# Name: Size, dtype: float64

# %%
sns.boxplot(df1['Size'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Size'>

# %%
df1['Size'].fillna(13.0,inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5472\197431760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Size'].fillna(13.0,inplace=True)

# %%
df1['Size'].describe()
# Out:
# count    10840.00000
# mean        20.18484
# std         20.97683
# min          0.00850
# 25%          5.90000
# 50%         13.00000
# 75%         26.00000
# max        100.00000
# Name: Size, dtype: float64

# %%
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df1['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10840, dtype: object

# %%
df1['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df1['Installs'].nunique()
# Out:
# 21

# %%
df1['Installs'].value_counts()
# Out:
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             907
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: Installs, dtype: int64

# %%
df1['Installs'] = df1['Installs'].apply(lambda x: int(x.replace('+','').replace(',','')))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5472\3131049472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Installs'] = df1['Installs'].apply(lambda x: int(x.replace('+','').replace(',','')))

# %%
df1['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,         50,        100,
#               500,         10,          1,          5,          0],
#       dtype=int64)

# %%
df1['Installs'].describe()
# Out:
# count    1.084000e+04
# mean     1.546434e+07
# std      8.502936e+07
# min      0.000000e+00
# 25%      1.000000e+03
# 50%      1.000000e+05
# 75%      5.000000e+06
# max      1.000000e+09
# Name: Installs, dtype: float64

# %%
df1.describe()
# Out:
#              Rating       Reviews         Size      Installs
# count  10840.000000  1.084000e+04  10840.00000  1.084000e+04
# mean       4.206476  4.441529e+05     20.18484  1.546434e+07
# std        0.480342  2.927761e+06     20.97683  8.502936e+07
# min        1.000000  0.000000e+00      0.00850  0.000000e+00
# 25%        4.100000  3.800000e+01      5.90000  1.000000e+03
# 50%        4.300000  2.094000e+03     13.00000  1.000000e+05
# 75%        4.500000  5.477550e+04     26.00000  5.000000e+06
# max        5.000000  7.815831e+07    100.00000  1.000000e+09

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10840 non-null  object
#  12  Android Ver     10840 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 1.4+ MB

# %%
df1['Price']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10836    0
# 10837    0
# 10838    0
# 10839    0
# 10840    0
# Name: Price, Length: 10840, dtype: object

# %%
df1['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df1['Price'].nunique()
# Out:
# 92

# %%
df1['Price'] = df1['Price'].apply(lambda x: float(x.replace('$','')))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5472\2624194095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Price'] = df1['Price'].apply(lambda x: float(x.replace('$','')))

# %%
df1['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10840 non-null  object
#  12  Android Ver     10840 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.4+ MB

# %%
df1.describe()
# Out:
#              Rating       Reviews         Size      Installs         Price
# count  10840.000000  1.084000e+04  10840.00000  1.084000e+04  10840.000000
# mean       4.206476  4.441529e+05     20.18484  1.546434e+07      1.027368
# std        0.480342  2.927761e+06     20.97683  8.502936e+07     15.949703
# min        1.000000  0.000000e+00      0.00850  0.000000e+00      0.000000
# 25%        4.100000  3.800000e+01      5.90000  1.000000e+03      0.000000
# 50%        4.300000  2.094000e+03     13.00000  1.000000e+05      0.000000
# 75%        4.500000  5.477550e+04     26.00000  5.000000e+06      0.000000
# max        5.000000  7.815831e+07    100.00000  1.000000e+09    400.000000

# %%
df1.describe(include='O')
# Out:
#            App Category   Type Content Rating Genres    Last Updated  \
# count    10840    10840  10840          10840  10840           10840
# unique    9659       33      2              6    119            1377
# top     ROBLOX   FAMILY   Free       Everyone  Tools  August 3, 2018
# freq         9     1972  10040           8714    842             326
#
#                Current Ver Android Ver
# count                10840       10840
# unique                2831          33
# top     Varies with device  4.1 and up
# freq                  1467        2453

# %%
df1['Content Rating']
# Out:
# 0          Everyone
# 1          Everyone
# 2          Everyone
# 3              Teen
# 4          Everyone
#             ...
# 10836      Everyone
# 10837      Everyone
# 10838      Everyone
# 10839    Mature 17+
# 10840      Everyone
# Name: Content Rating, Length: 10840, dtype: object

# %%
df1['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
sns.countplot(df1['Content Rating'])
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %%
df1['Content Rating'].nunique()
# Out:
# 6

# %%
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size  Installs  Type  Price Content Rating  \
# 0     159.0  19.0     10000  Free    0.0       Everyone
# 1     967.0  14.0    500000  Free    0.0       Everyone
# 2   87510.0   8.7   5000000  Free    0.0       Everyone
# 3  215644.0  25.0  50000000  Free    0.0           Teen
# 4     967.0   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          10840 non-null  float64
#  3   Reviews         10840 non-null  float64
#  4   Size            10840 non-null  float64
#  5   Installs        10840 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10840 non-null  object
#  12  Android Ver     10840 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.4+ MB

# %%
df1.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.063166  0.053447  0.045496 -0.019318
# Reviews   0.063166  1.000000  0.104027  0.643122 -0.009667
# Size      0.053447  0.104027  1.000000  0.047691 -0.019370
# Installs  0.045496  0.643122  0.047691  1.000000 -0.011689
# Price    -0.019318 -0.009667 -0.019370 -0.011689  1.000000

# %%
sns.heatmap(df1.corr())
# Out:
# <AxesSubplot:>

# %% [raw]
#  Observations:
#
# - Category column has 34 unique values in which 'Family' is most common value
#
# - Type column has 3 unique values out of which 'Free' is the most common value
#
# - Price column has 93 unique value out of which '0' is the most common value
#
# - Rating column has maximum rating of 4.4 (1109 counts) and avg rating is 4.20
#
# - Most Common android ver is 4.1 and up

# %%
# import sklearn

# from sklearn.model_selection import train_test_split

# import statsmodels

# import statsmodels.api as sm

# %%
# x_train, x_test, y_train, y_test = train_test_split(df1.Reviews, df1.Installs, test_size = 0.2)

# %%
# x_train=sm.add_constant(x_train)

# %%
# mod1=sm.OLS(y_train,x_train).fit()

# %%
# print(mod1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               Installs   R-squared:                       0.409
# Model:                            OLS   Adj. R-squared:                  0.409
# Method:                 Least Squares   F-statistic:                     6000.
# Date:                Thu, 05 Jan 2023   Prob (F-statistic):               0.00
# Time:                        23:30:06   Log-Likelihood:            -1.6816e+05
# No. Observations:                8672   AIC:                         3.363e+05
# Df Residuals:                    8670   BIC:                         3.363e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.308e+06   6.93e+05     10.538      0.000    5.95e+06    8.67e+06
# ...

# %%
# df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size  Installs  Type  Price Content Rating  \
# 0     159.0  19.0     10000  Free    0.0       Everyone
# 1     967.0  14.0    500000  Free    0.0       Everyone
# 2   87510.0   8.7   5000000  Free    0.0       Everyone
# 3  215644.0  25.0  50000000  Free    0.0           Teen
# 4     967.0   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# dc = df1[['Rating','Reviews','Size','Installs','Price']]

# %%
# x_train, x_test, y_train, y_test = train_test_split(dc.drop('Price', axis=1), dc.Price, test_size=0.2)

# %%
# x_train=sm.add_constant(x_train)

# %%
# mod2=sm.OLS(y_train, x_train).fit()

# %%
# print(mod2.summary())

# %%
# df1.describe(include='O')

# %%
# df1.head()

# %%
# sns.countplot(df1['Rating'])

# %%
# df1['Content Rating'].value_counts()

# %%
# content_dummy=pd.get_dummies(df['Content Rating'])
# content_dummy.head()

# %%
df2 = df1.copy()

# %%
df2.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size  Installs  Type  Price Content Rating  \
# 0     159.0  19.0     10000  Free    0.0       Everyone
# 1     967.0  14.0    500000  Free    0.0       Everyone
# 2   87510.0   8.7   5000000  Free    0.0       Everyone
# 3  215644.0  25.0  50000000  Free    0.0           Teen
# 4     967.0   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df3 = pd.concat([df2, content_dummy], axis=1)

# %%
df3.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size    Installs  Type  Price Content Rating  \
# 0     159.0  19.0     10000.0  Free    0.0       Everyone
# 1     967.0  14.0    500000.0  Free    0.0       Everyone
# 2   87510.0   8.7   5000000.0  Free    0.0       Everyone
# 3  215644.0  25.0  50000000.0  Free    0.0           Teen
# 4     967.0   2.8    100000.0  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...
